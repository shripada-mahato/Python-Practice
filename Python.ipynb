# %% [markdown]
# <a href="https://colab.research.google.com/github/shripada-mahato/Python-Practice/blob/main/Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def calculate(**kwargs):
  sum = 0
  for i in kwargs.values():
    sum += i
  return sum
print(calculate(a=10,b=20,c=30))
# Out:
# 60

# %%
def calculate_average(**kwargs):
  total = 0
  count = 0
  for i in kwargs.values():
    total += i
    count += 1
  return total / count
print(calculate_average(
    python=80,
    java=70,
    sql=90,
    c=100
))
# Out:
# 85.0

# %%
def find_high_scores(**kwargs):

    high_scores = []

    for subject, mark in kwargs.items():

        if mark >= 80:
           subject.apeand(high_scores)
    return high_scores
print(find_high_scores(
    python=85,
    java=72,
    sql=90,
    c=65,
    ml=88
))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_2007/1631664611.py in <cell line: 0>()
#       8            subject.apeand(high_scores)
#       9     return high_scores
# ---> 10 print(find_high_scores(
#      11     python=85,
#      12     java=72,
#
# /tmp/ipykernel_2007/1631664611.py in find_high_scores(**kwargs)
#       6
#       7         if mark >= 80:
# ----> 8            subject.apeand(high_scores)
#       9     return high_scores
#      10 print(find_high_scores(
#
# AttributeError: 'str' object has no attribute 'apeand'
